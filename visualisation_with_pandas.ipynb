# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df1=sns.load_dataset('tips')
df2=pd.read_csv('204.ece.csv')

# %%
x1=np.random.rand(100,5)
x2=np.random.rand(10,5)

# %%
df3=pd.DataFrame(x1,columns=['a','b','c','d','e'])
df3
# Out:
#            a         b         c         d         e
# 0   0.463046  0.836018  0.950294  0.948741  0.684154
# 1   0.380169  0.576393  0.138687  0.348337  0.068299
# 2   0.788339  0.370727  0.258343  0.662518  0.465182
# 3   0.732493  0.236696  0.140533  0.056548  0.718902
# 4   0.834001  0.968486  0.588959  0.390959  0.451359
# ..       ...       ...       ...       ...       ...
# 95  0.473837  0.586818  0.738017  0.498475  0.859951
# 96  0.173192  0.283461  0.946207  0.196000  0.492071
# 97  0.554811  0.184651  0.805776  0.224998  0.718815
# 98  0.000307  0.010266  0.517433  0.162811  0.303243
# 99  0.855003  0.907598  0.106707  0.468572  0.640280
#
# [100 rows x 5 columns]

# %%
df4=pd.DataFrame(x2,columns=['a','b','c','d','e'])
df4
# Out:
#           a         b         c         d         e
# 0  0.828994  0.532671  0.377724  0.928969  0.379433
# 1  0.340548  0.432284  0.342199  0.311050  0.708560
# 2  0.639849  0.287310  0.843118  0.198191  0.568393
# 3  0.275908  0.401482  0.073835  0.399681  0.326107
# 4  0.342655  0.230674  0.127104  0.551835  0.702755
# 5  0.106559  0.547874  0.161059  0.512433  0.968518
# 6  0.023255  0.972496  0.536164  0.247598  0.196323
# 7  0.308271  0.426124  0.335632  0.445812  0.588105
# 8  0.708520  0.501467  0.977261  0.485987  0.600917
# 9  0.332144  0.328606  0.703017  0.568200  0.681346

# %%
df3.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1.plot.scatter(x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3['a'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>],
#        [<AxesSubplot:title={'center':'e'}>, <AxesSubplot:>]], dtype=object)

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area(alpha=0.5)# aplha used  to color contrast
# Out:
# <AxesSubplot:>

# %%
#we can also plot like this
df4.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hexbin(x='total_bill',y='tip',gridsize=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
